# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Datasets/train.csv")
df.head()
# Out:
#   Customer ID               Name Gender  Age  Income (USD) Income Stability  \
# 0     C-36995   Frederica Shealy      F   56       1933.05              Low
# 1     C-33999  America Calderone      M   32       4952.91              Low
# 2      C-3770      Rosetta Verne      F   65        988.19             High
# 3     C-26480         Zoe Chitty      F   65           NaN             High
# 4     C-23459       Afton Venema      F   31       2614.77              Low
#
#   Profession     Type of Employment    Location  Loan Amount Request (USD)  \
# 0    Working            Sales staff  Semi-Urban                   72809.58
# 1    Working                    NaN  Semi-Urban                   46837.47
# 2  Pensioner                    NaN  Semi-Urban                   45593.04
# 3  Pensioner                    NaN       Rural                   80057.92
# 4    Working  High skill tech staff  Semi-Urban                  113858.89
#
#    ...  Credit Score No. of Defaults Has Active Credit Card  Property ID  \
# 0  ...        809.44               0                    NaN          746
# 1  ...        780.40               0            Unpossessed          608
# 2  ...        833.15               0            Unpossessed          546
# 3  ...        832.70               1            Unpossessed          890
# 4  ...        745.55               1                 Active          715
#
#    Property Age  Property Type Property Location  Co-Applicant  \
# 0       1933.05              4             Rural             1
# 1       4952.91              2             Rural             1
# 2        988.19              2             Urban             0
# 3           NaN              2        Semi-Urban             1
# 4       2614.77              4        Semi-Urban             1
#
#    Property Price  Loan Sanction Amount (USD)
# 0       119933.46                    54607.18
# 1        54791.00                    37469.98
# 2        72440.58                    36474.43
# 3       121441.51                    56040.54
# 4       208567.91                    74008.28
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (30000, 24)

# %%
df.columns
# Out:
# Index(['Customer ID', 'Name', 'Gender', 'Age', 'Income (USD)',
#        'Income Stability', 'Profession', 'Type of Employment', 'Location',
#        'Loan Amount Request (USD)', 'Current Loan Expenses (USD)',
#        'Expense Type 1', 'Expense Type 2', 'Dependents', 'Credit Score',
#        'No. of Defaults', 'Has Active Credit Card', 'Property ID',
#        'Property Age', 'Property Type', 'Property Location', 'Co-Applicant',
#        'Property Price', 'Loan Sanction Amount (USD)'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Customer ID                       0
# Name                              0
# Gender                           53
# Age                               0
# Income (USD)                   4576
# Income Stability               1683
# Profession                        0
# Type of Employment             7270
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)     172
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                     2493
# Credit Score                   1703
# No. of Defaults                   0
# Has Active Credit Card         1566
# Property ID                       0
# Property Age                   4850
# Property Type                     0
# Property Location               356
# Co-Applicant                      0
# Property Price                    0
# Loan Sanction Amount (USD)      340
# dtype: int64

# %%
df.dropna(how='all', inplace=True)

# %%
df.dropna(subset=['Loan Sanction Amount (USD)'], inplace=True)

# %%
df.describe().T
# Out:
#                                count           mean           std      min  \
# Age                          29660.0      40.099225     16.050024    18.00
# Income (USD)                 25167.0    2630.990563  11319.018008   377.70
# Loan Amount Request (USD)    29660.0   88792.057274  59480.995253  6048.24
# Current Loan Expenses (USD)  29493.0     400.893752    242.265401  -999.00
# Dependents                   27214.0       2.253399      0.951987     1.00
# Credit Score                 27990.0     739.853475     72.152128   580.00
# No. of Defaults              29660.0       0.194066      0.395487     0.00
# Property ID                  29660.0     501.881827    288.160738     1.00
# Property Age                 24900.0    2631.317285  11378.314324   377.70
# Property Type                29660.0       2.460013      1.118695     1.00
# Co-Applicant                 29660.0      -4.707788     74.369350  -999.00
# Property Price               29660.0  131733.517170  93421.288272  -999.00
# Loan Sanction Amount (USD)   29660.0   47649.342208  48221.146686  -999.00
#
#                                     25%         50%          75%         max
# Age                             25.0000      40.000      55.0000       65.00
# Income (USD)                  1650.2500    2223.300    3090.3300  1777460.21
# Loan Amount Request (USD)    41200.1125   75114.085  119890.8575   621497.82
# Current Loan Expenses (USD)    247.7800     375.090     521.0500     3840.88
# Dependents                       2.0000       2.000       3.0000       14.00
# Credit Score                   681.7325     739.815     799.0400      896.26
# No. of Defaults                  0.0000       0.000       0.0000        1.00
# Property ID                    251.0000     504.000     751.0000      999.00
# Property Age                  1649.8100    2223.965    3090.8325  1777460.21
# Property Type                    1.0000       2.000       3.0000        4.00
# Co-Applicant                     1.0000       1.000       1.0000        1.00
# Property Price               60658.7400  109993.610  178801.9050  1077966.73
# Loan Sanction Amount (USD)       0.0000   35209.395   74261.2500   481907.32

# %%
df['Property Price'].replace(-999.00, np.nan)
df['Loan Sanction Amount (USD)'].replace(-999.00, np.nan)
# Out:
# 0         54607.18
# 1         37469.98
# 2         36474.43
# 3         56040.54
# 4         74008.28
#            ...
# 29995     68992.11
# 29996     46616.60
# 29997     61057.56
# 29998     99766.87
# 29999    117217.90
# Name: Loan Sanction Amount (USD), Length: 29660, dtype: float64

# %%
df.drop(columns=['Customer ID', 'Property ID', 'Name'], inplace=True, axis=1)

# %%
sns.histplot(df['Loan Sanction Amount (USD)'])
plt.savefig('Screenshots/Loan_amount_histplot.png')

# %%
print("Target Value - Zero vs Non-zero")
zero_count=len(df[df['Loan Sanction Amount (USD)']==0])
print("Loan Amount is Zero for", zero_count*100/len(df), " %")
non_zero_count=len(df[df['Loan Sanction Amount (USD)']>0])
print("Loan Amount is Non-Zero for", non_zero_count*100/len(df), " %")
# Out:
# Target Value - Zero vs Non-zero
# Loan Amount is Zero for 26.517194875252866  %
# Loan Amount is Non-Zero for 72.34322319622387  %

# %%
df['Location'].value_counts()
# Out:
# Location
# Semi-Urban    21317
# Rural          5280
# Urban          3063
# Name: count, dtype: int64

# %%
sns.countplot(x="Type of Employment", data=df)
plt.savefig('Screenshots/type_of_employ_countplot.png')

# %%
df['Type of Employment'].value_counts()
# Out:
# Type of Employment
# Laborers                 5516
# Sales staff              3698
# Core staff               3189
# Managers                 2464
# Drivers                  1588
# Accountants              1363
# High skill tech staff    1297
# Medicine staff            854
# Security staff            574
# Cooking staff             561
# Cleaning staff            338
# Private service staff     337
# Secretaries               158
# Low-skill Laborers        154
# Waiters/barmen staff      148
# Realty agents              85
# IT staff                   77
# HR staff                   71
# Name: count, dtype: int64

# %%
df['Profession'].value_counts()
# Out:
# Profession
# Working                 16739
# Commercial associate     7863
# Pensioner                2718
# State servant            2334
# Unemployed                  2
# Businessman                 2
# Student                     1
# Maternity leave             1
# Name: count, dtype: int64

# %%
sns.countplot(x='Property Type', data=df)
plt.savefig('Screenshots/Property_type_countplot.png')

# %%
sns.histplot(df['Income (USD)'])
plt.savefig('Screenshots/income_amount_histplot.png')

# %%
from sklearn.model_selection import train_test_split
Y=df['Loan Sanction Amount (USD)']
X=df.drop('Loan Sanction Amount (USD)', axis=1)
X_train, X_test, y_train, y_test=train_test_split(X, Y, random_state=42, test_size=0.2)
print(f"Test Size: {len(X_test)}")
# Out:
# Test Size: 5932

# %%
num_cols=list(X.select_dtypes(include=['int64', 'float64']).columns)
cat_cols=list(X.select_dtypes(include=['object']).columns)
print("Numerical Columns: ",'\n', num_cols)
# Out:
# Numerical Columns:
#  ['Age', 'Income (USD)', 'Loan Amount Request (USD)', 'Current Loan Expenses (USD)', 'Dependents', 'Credit Score', 'No. of Defaults', 'Property Age', 'Property Type', 'Co-Applicant', 'Property Price']

# %%
df.dtypes
# Out:
# Gender                          object
# Age                              int64
# Income (USD)                   float64
# Income Stability                object
# Profession                      object
# Type of Employment              object
# Location                        object
# Loan Amount Request (USD)      float64
# Current Loan Expenses (USD)    float64
# Expense Type 1                  object
# Expense Type 2                  object
# Dependents                     float64
# Credit Score                   float64
# No. of Defaults                  int64
# Has Active Credit Card          object
# Property Age                   float64
# Property Type                    int64
# Property Location               object
# Co-Applicant                     int64
# Property Price                 float64
# Loan Sanction Amount (USD)     float64
# dtype: object

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', MinMaxScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ordinalencoder', OrdinalEncoder( handle_unknown='use_encoded_value',
        unknown_value=-1))
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, num_cols),
        ('cat', categorical_transformer, cat_cols)
    ],
    remainder='drop' 
)

model_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor)
])

# %%
model_pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    MinMaxScaler())]),
#                                                   ['Age', 'Income (USD)',
#                                                    'Loan Amount Request (USD)',
#                                                    'Current Loan Expenses '
#                                                    '(USD)',
#                                                    'Dependents', 'Credit Score',
#                                                    'No. of Defaults',
#                                                    'Property Age',
#                                                    'Property Type',
#                                                    'Co-Applicant',
#                                                    'Property Price']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ordinalencoder',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   ['Gender', 'Income Stability',
#                                                    'Profession',
#                                                    'Type of Employment',
#                                                    'Location', 'Expense Type 1',
#                                                    'Expense Type 2',
#                                                    'Has Active Credit Card',
#                                                    'Property Location'])]))])

# %%
X_train_prep=model_pipeline.fit_transform(X_train)

# %%
X_test_prep=model_pipeline.transform(X_test)

# %%
X_train_prep[:5]
# Out:
# array([[9.36170213e-01, 4.31392462e-04, 4.36737576e-02, 2.34627718e-01,
#         0.00000000e+00, 8.70707646e-01, 0.00000000e+00, 4.31392462e-04,
#         6.66666667e-01, 1.00000000e+00, 4.37241403e-02, 0.00000000e+00,
#         0.00000000e+00, 2.00000000e+00, 8.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.00000000e+00],
#        [2.97872340e-01, 2.13566336e-03, 6.36834029e-03, 2.22660479e-01,
#         0.00000000e+00, 9.55384810e-01, 0.00000000e+00, 2.13566336e-03,
#         1.00000000e+00, 1.00000000e+00, 1.61041062e-02, 0.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 8.00000000e+00, 1.00000000e+00,
#         0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 2.00000000e+00],
#        [9.78723404e-01, 2.09750531e-03, 4.36185119e-01, 4.10235378e-01,
#         0.00000000e+00, 5.06070146e-01, 0.00000000e+00, 2.09750531e-03,
#         3.33333333e-01, 1.00000000e+00, 4.69952957e-01, 0.00000000e+00,
#         1.00000000e+00, 6.00000000e+00, 8.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 0.00000000e+00, 2.00000000e+00, 0.00000000e+00],
#        [9.57446809e-01, 1.97984054e-03, 1.64106334e-01, 3.13642074e-01,
#         7.69230769e-02, 7.84006830e-01, 0.00000000e+00, 1.97984054e-03,
#         3.33333333e-01, 1.00000000e+00, 1.19309339e-01, 0.00000000e+00,
#         0.00000000e+00, 2.00000000e+00, 8.00000000e+00, 2.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.00000000e+00],
#        [3.40425532e-01, 9.32044512e-04, 2.32722963e-01, 3.33861583e-01,
#         0.00000000e+00, 1.51805477e-01, 0.00000000e+00, 9.32044512e-04,
#         3.33333333e-01, 1.00000000e+00, 2.20945123e-01, 0.00000000e+00,
#         1.00000000e+00, 6.00000000e+00, 6.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 2.00000000e+00, 2.00000000e+00]])

# %%
#sns.pairplot(df)

# %%
from sklearn.linear_model import LinearRegression
linreg= LinearRegression()
linreg
# Out:
# LinearRegression()

# %%
lr_scoring = {
    'r2': 'r2',
    'mae': make_scorer(mean_absolute_error, greater_is_better=False),
    'mse': make_scorer(mean_squared_error, greater_is_better=False),
    'rmse': make_scorer(mean_squared_error, greater_is_better=False, squared=False)
    }

lr_cv=cross_validate(
    linreg,
    X_train_prep,
    y_train,
    cv=5,
    scoring=lr_scoring
)

cv_r2   = lr_cv['test_r2'].mean()
cv_mae  = -lr_cv['test_mae'].mean()
cv_mse  = -lr_cv['test_mse'].mean()
cv_rmse = -lr_cv['test_rmse'].mean()

#__________________________
print("Linear Regression CV MSE: ",  cv_mse)
print("Linear Regression CV MAE: ", cv_mae)
print("Linear Regression CV RMSE: ", cv_rmse)
print("Linear Regression CV R2 Score: ", cv_r2)
# Out:
# Linear Regression CV MSE:  968542799.6044391
# Linear Regression CV MAE:  21505.482958693217
# Linear Regression CV RMSE:  31114.931302785688
# Linear Regression CV R2 Score:  0.5854362122963677
# E:\Anaconda\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# E:\Anaconda\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# E:\Anaconda\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# E:\Anaconda\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# E:\Anaconda\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import root_mean_squared_error, r2_score

# %%
linreg.fit(X_train_prep, y_train)
y_pred=linreg.predict(X_test_prep)
#__________________________
print("Linear Regression MSE: ",  mean_squared_error(y_test, y_pred))
print("Linear Regression MAE: ", mean_absolute_error(y_test, y_pred))
print("Linear Regression RMSE: ", root_mean_squared_error(y_test, y_pred))
print("Linear Regression R2 Score: ", r2_score(y_test, y_pred))
# Out:
# Linear Regression MSE:  1018202947.1589785
# Linear Regression MAE:  21581.585139716466
# Linear Regression RMSE:  31909.29248916338
# Linear Regression R2 Score:  0.5514078943383847

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_validate
from sklearn.metrics import make_scorer, mean_absolute_error, mean_squared_error

def best_model_metrics(metrics_df, model_name, model, param_grid):
    search=GridSearchCV(estimator=model,
                   param_grid=param_grid,
                   cv=5,
                   scoring='r2',
                   n_jobs=-1
                   )
    search.fit(X_train_prep, y_train)
    print(f"Best Parameters of {model_name}: ")
    print(search.best_params_)
    print("Best R2 Score: ")
    print(search.best_score_)
    
    #--------Cross Validation---------
    scoring = {
    'r2': 'r2',
    'mae': make_scorer(mean_absolute_error, greater_is_better=False),
    'mse': make_scorer(mean_squared_error, greater_is_better=False),
    'rmse': make_scorer(mean_squared_error, greater_is_better=False, squared=False)
    }

    cv_results = cross_validate(
        search.best_estimator_,
        X_train_prep,
        y_train,
        cv=5,
        scoring=scoring
    )
    cv_r2   = cv_results['test_r2'].mean()
    cv_mae  = -cv_results['test_mae'].mean()
    cv_mse  = -cv_results['test_mse'].mean()
    cv_rmse = -cv_results['test_rmse'].mean()

    #----------Test Performance--------------
    
    model=search.best_estimator_
    model.fit(X_train_prep, y_train)
    print(f"Coeffiecients of {model_name}")
    print(model.coeff_)
    y_pred=model.predict(X_test_prep)
    t=y_test
    p=y_pred

    #-----------Plots----------------------
    sns.lineplot()
    
    #-----------Storing Metrics--------------
    length=len(metrics_df)
    metrics_df.loc[length+1]=([model_name+' cv', cv_mse, cv_mae, cv_rmse, cv_r2])
    metrics_df.loc[length+2]=([model_name, mean_squared_error(t, p), mean_absolute_error(t,p), root_mean_squared_error(t,p), r2_score(t,p)])

# %%
from sklearn import linear_model
lasso=linear_model.Lasso()
lasso
# Out:
# Lasso()

# %%
cols=['model', 'MSE', 'MAE', 'RMSE', 'r2 score']
best_metrics = pd.DataFrame(columns=cols)

# %%
param_grid={
    "alpha":[0.001, 0.01, 0.1, 10]
}
best_model_metrics(best_metrics, "Lasso Regression", lasso, param_grid)
# Out:
# Best Parameters of Lasso Regression:
# {'alpha': 10}
# Best R2 Score:
# 0.5912101191835581
# E:\Anaconda\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# E:\Anaconda\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# E:\Anaconda\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# E:\Anaconda\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# E:\Anaconda\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
from sklearn.linear_model import Ridge
ridge=Ridge()
ridge
# Out:
# Ridge()

# %%
param_grid={
    "alpha":[0.001, 0.01, 10, 100]
}
best_model_metrics(best_metrics, "Ridge Regression", ridge, param_grid)
# Out:
# Best Parameters of Ridge Regression:
# {'alpha': 0.01}
# Best R2 Score:
# 0.5881064018310641
# E:\Anaconda\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# E:\Anaconda\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# E:\Anaconda\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# E:\Anaconda\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# E:\Anaconda\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
from sklearn.linear_model import ElasticNet
elastic=ElasticNet()
elastic
# Out:
# ElasticNet()

# %%
param_grid={
    "alpha":[0.001, 0.1, 1, 10],
    "l1_ratio":[0.2, 0.5, 0.8]
}
best_model_metrics(best_metrics, "Elastic Net", elastic, param_grid)
# Out:
# Best Parameters of Elastic Net:
# {'alpha': 0.001, 'l1_ratio': 0.8}
# Best R2 Score:
# 0.5900113526373545
# E:\Anaconda\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# E:\Anaconda\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# E:\Anaconda\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# E:\Anaconda\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# E:\Anaconda\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
best_metrics
# Out:
#                  model           MSE           MAE          RMSE  r2 score
# 1  Lasso Regression cv  9.545941e+08  21494.827945  30886.197104  0.591210
# 2     Lasso Regression  1.016550e+09  21578.193457  31883.388763  0.552136
# 3  Ridge Regression cv  9.620821e+08  21498.117466  31009.847353  0.588106
# 4     Ridge Regression  1.017962e+09  21567.718324  31905.523324  0.551514
# 5       Elastic Net cv  9.574273e+08  21587.386713  30932.852548  0.590011
# 6          Elastic Net  1.015952e+09  21649.776432  31874.006806  0.552399
